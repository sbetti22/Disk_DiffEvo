# %%
import os
import glob
import yaml

import math as mt
import numpy as np  
import pandas as pd 

import numpy.ma as ma

import matplotlib
import matplotlib.pyplot as plt

import astropy.io.fits as fits
from astropy.convolution import convolve
from astropy.wcs import FITSFixedWarning
from astropy.convolution import convolve
from astropy import constants as const
from astropy import units as u
from astropy.convolution import Gaussian2DKernel, convolve
from astropy.visualization import ZScaleInterval
interval = ZScaleInterval()

from pyklip.fmlib.diskfm import DiskFM

import time
from datetime import datetime

from scipy.optimize import differential_evolution

import shutil
import subprocess

import mcfost # mcfost-master analysis code from https://github.com/mperrin/mcfost-python, The folder called mcfost MUST be in the same folder as this code to run! 
import disk_convolution as dc
import DE_plot
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
########################################################
# CHANGE THIS TO THE PARAMETER FILE YOU WANT TO USE!!
yaml_paramater_file = 'de_parameter_file.yaml'
########################################################

# %%
DE_plot.run_doplot(yaml_paramater_file, make_files=False, param_plot=True, model_plot=True, 
                  paramplot_kw={'vmin':3.2, 
                                    'vmax':3.8,
                                    'ylim_min':3},
                  modelplot_kw = {'stretch':'sqrt',
                                  'vmin':0,
                                  'vmax':0.1,
                                  'origvmin':0,
                                  'origvmax':2e-5,
                                  'resvmin':-0.1,
                                  'resvmax':0.1})
# Out:
# starting plotting
# opening FINAL csv file
# [80.55465267714509, 6.193754943561026, 3.3819037242076102e-09, 1.1189236637908806, 1.1367776324551706, 1.8095256576337335, 1.3997132149178433, 0.751705038128223, 1.3472467084507516, 0.1196284507981263, 2.701635731014255]
# min/max chi2:  3.1409817451404143 / 244338.5616422558
#   name   min(x) max(x) min(chi2) max(chi2) horline
# -------- ------ ------ --------- --------- -------
#        I   75.0  84.98      3.14 244338.56    3.37
#       H0   2.01   10.0      3.14 244338.56    3.33
#    MDUST    0.0    0.0      3.14 244338.56    3.44
#     BETA    1.0    4.0      3.14 244338.56     3.3
#        F    1.0    2.0      3.14 244338.56    3.63
#     AMIN    1.0   4.99      3.14 244338.56    3.18
#     AEXP    1.0    3.0      3.14 244338.56    3.56
# POROSITY   0.01   0.99      3.14 244338.56    4.11
#  DUSTSET    0.0   2.99      3.14 244338.56    3.84
# ALPH_VIS   0.01    2.0      3.14 244338.56    3.18
#      AMP    0.1   4.99      3.14 244338.56    3.29
#    ==> using existing fits files
# 0.0014280174268454988
# 0.002315563
# FINISHED!
